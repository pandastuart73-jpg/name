# %%
import pandas as pd

# %%
student_data ={
    "Name":["stuart","mimi","ronnie","joyce","sylvia","tracy"],
    "science":[90, 80, 70, 60, 50,78],
    "maths":[87, 90, 78, 89, 99,67],
    "Gender":["Male","Female","Male","Female","Female","female"],
    "Age":[29,21,23,34,27,29]
}
students = pd.DataFrame(student_data)
students
# Out:
#      Name  science  maths  Gender  Age
# 0  stuart       90     87    Male   29
# 1    mimi       80     90  Female   21
# 2  ronnie       70     78    Male   23
# 3   joyce       60     89  Female   34
# 4  sylvia       50     99  Female   27
# 5   tracy       78     67  female   29

# %% [markdown]
# - exercise1
# - find the mean science mark and explain ur results
# - find the median of science mark and list the students attached to that mark

# %%
students["science"].mean()
# Out:
# np.float64(71.33333333333333)

# %% [markdown]
# the mean of the science mark is 71.33

# %%
students["science"].median()
# Out:
# np.float64(74.0)

# %% [markdown]
# exicise2
# - find the spread of math marks using var
# - whats the range of math marks and comment

# %%
students["maths"].var()
# Out:
# np.float64(122.8)

# %%
students["maths"].max()-students["maths"].min()
# Out:
# np.int64(32)

# %% [markdown]
# the range of math marks is 32
